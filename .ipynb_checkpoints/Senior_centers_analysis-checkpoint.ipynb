# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('./data/Responses_By_Center.csv', encoding='latin-1')
data.head()
# Out:
#    SurveyYear  SurveyPeriod                   SiteName StartDate  EndDate  \
# 0        2015             1  Wallingford Senior Center   00:00.0  00:00.0
# 1        2015             1  Wallingford Senior Center   00:00.0  00:00.0
# 2        2015             1  Wallingford Senior Center   00:00.0  00:00.0
# 3        2015             1  Wallingford Senior Center   00:00.0  00:00.0
# 4        2015             1  Wallingford Senior Center   00:00.0  00:00.0
#
#                      Race                              EstimatedAnnualIncome  \
# 0     White or Caucasian   Moderate: Less than $44,750 for 1 person; or $...
# 1     White or Caucasian   Moderate: Less than $44,750 for 1 person; or $...
# 2     White or Caucasian   Moderate: Less than $44,750 for 1 person; or $...
# 3     White or Caucasian   Very Low:  Less than $18,550 for 1 person; or ...
# 4  Asian, Asian-American   Low:  Less than $30,900 for 1 person; or $35,3...
#
#   ZipCode  SurveyResponseID Q1 - DoMoreVolunteerWork  \
# ...

# %%
center_names = data.SiteName.unique()
print(center_names)
# Out:
# ['Wallingford Senior Center' 'South Park Senior Center'
#  'Greenwood Senior Center' 'Sunshine Garden' 'Pike Market Senior Center'
#  'ACRS' 'Southeast Senior Center' 'Ballard NW Senior Center'
#  'West Seattle Senior Center' 'Central Area Senior Center' 'IDIC' 'CISC'
#  'South Park']

# %%
# income_distr = data.EstimatedAnnualIncome.unique()
# data.groupby("SiteName").size()
# plt.figure(figsize=(10,8))

# y_pos = np.arange(len(income_distr))
# plt.bar(income_distr, data.groupby("SiteName").size(), align='center', alpha=0.5)
# plt.xticks(y_pos, income_distr,rotation=70)
# plt.title("Number of responses per senior center")
# plt.show()

# %%
data['Q1 - DoMoreVolunteerWork'].unique()
data['Q14 - WouldRecommendSeniorCenter'].count()
# Out:
# 6650

# %%
plt.figure(figsize=(10,8))

center_names = data.SiteName.unique()
y_pos = np.arange(len(center_names))
plt.bar(center_names, data.groupby("SiteName").size(), align='center', alpha=0.5)
plt.xticks(y_pos, center_names,rotation=70)
plt.title("Number of responses per senior center")
plt.show()

# %%
# plt.hist(data)
# plt.xticks(data.SiteName.unique())
# plt.xlabel("Senior Center")
# plt.ylabel("Count")
# plt.title("Distribution of Annual Income")
# plt.show()
